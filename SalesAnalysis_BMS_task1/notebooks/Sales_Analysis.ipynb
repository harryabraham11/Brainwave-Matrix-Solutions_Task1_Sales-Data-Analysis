# %% [markdown]
# An Exploratory Sales Data Analysis for a Supermarket

# %%
#importing pandas library
import pandas as pd

# %%
#loading the dataset
data_frame = pd.read_csv("../data/Sample - Superstore.csv", encoding='latin1')

# %%
#preview of the Data
data_frame.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#Obtaining the basic Info of the Dataset
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#Summary statistics for numerical columns
data_frame.describe(include='all')
# Out:
#              Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   9994.000000            9994       9994        9994            9994
# unique          NaN            5009       1237        1334               4
# top             NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq            NaN              14         38          35            5968
# mean    4997.500000             NaN        NaN         NaN             NaN
# std     2885.163629             NaN        NaN         NaN             NaN
# min        1.000000             NaN        NaN         NaN             NaN
# 25%     2499.250000             NaN        NaN         NaN             NaN
# 50%     4997.500000             NaN        NaN         NaN             NaN
# 75%     7495.750000             NaN        NaN         NaN             NaN
# max     9994.000000             NaN        NaN         NaN             NaN
#
# ...

# %%
# Checking for null values column-wise
data_frame.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
#Checking for duplicate rows
data_frame.duplicated().sum()
data_frame.drop_duplicates(inplace=True)

# %%
# Converting the  date columns to datetime format
data_frame['Order Date'] = pd.to_datetime(data_frame['Order Date'])
data_frame['Ship Date'] = pd.to_datetime(data_frame['Ship Date'])

# %%
duplicates = data_frame.duplicated()
print("Number of duplicate rows:", duplicates.sum())
# Out:
# Number of duplicate rows: 0

# %%
#Order Month
data_frame['Order Month'] = data_frame['Order Date'].dt.to_period('M')

# %%
#Shipping duration
data_frame['Shipping Duration'] = (data_frame['Ship Date'] - data_frame['Order Date']).dt.days

# %%
#Profit Margin
data_frame['Profit Margin'] = (data_frame['Profit'] / data_frame['Sales']).round(2)

# %%
#Sales per Unit
data_frame['Sales per Unit'] = (data_frame['Sales'] / data_frame['Quantity']).round(2)

# %%
#Discount Flag
data_frame['Is Discounted'] = data_frame['Discount'].apply(lambda x: 1 if x > 0 else 0)

# %%
#importing Matplotlib and Seaborn libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Making the plots look better
plt.style.use('ggplot')
sns.set_palette('Set2')

# %%
#Sales and Profit Overview
print("Total Sales: ₹", round(data_frame['Sales'].sum(), 2))
print("Total Profit: ₹", round(data_frame['Profit'].sum(), 2))
print("Total Quantity Sold:", data_frame['Quantity'].sum())
print("Average Discount:", round(data_frame['Discount'].mean(), 2))
# Out:
# Total Sales: ₹ 2297200.86
# Total Profit: ₹ 286397.02
# Total Quantity Sold: 37873
# Average Discount: 0.16

# %%
#Sales and profit by category
category_group = data_frame.groupby('Category')[['Sales', 'Profit']].sum().sort_values('Sales', ascending=False)
category_group.plot(kind='bar', figsize=(8,5), title='Sales vs Profit by Category')
plt.ylabel('Amount in Rs')
plt.savefig('Reports/sales_by_category.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[111], line 5
#       3 category_group.plot(kind='bar', figsize=(8,5), title='Sales vs Profit by Category')
#       4 plt.ylabel('Amount in Rs')
# ----> 5 plt.savefig('reports/sales_by_category.png')
#       6 plt.show()
#
# File c:\Users\harry\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File c:\Users\harry\anaconda3\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
# ...

# %%
#Top 10 Products by Sales
top_products = data_frame.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
top_products.plot(kind='barh', figsize=(8,5), title='Top 10 Products by Sales')
plt.xlabel('Sales')
plt.show()

# %%
#Monthly Sales Trend
monthly_sales = data_frame.groupby('Order Month')['Sales'].sum()
monthly_sales.plot(kind='line', marker='o', figsize=(10,5), title='Monthly Sales Trend')
plt.ylabel('Sales')
plt.xticks(rotation=0)
plt.show()

# %%
#Segment-wise Profitability
segment_profit = data_frame.groupby('Segment')['Profit'].sum()
segment_profit.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(6,6), title='Profit Distribution by Segment')
plt.ylabel('')
plt.show()

# %%
#Obtaining the Cleaned Dataset
data_frame.to_csv("Sample(CLEANED)- Superstore.csv")

# %%
#Saving the Plot Images
plt.savefig('reports/sales_by_category.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[109], line 2
#       1 #Saving the Plot Images
# ----> 2 plt.savefig('reports/sales_by_category.png')
#
# File c:\Users\harry\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File c:\Users\harry\anaconda3\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# ...
